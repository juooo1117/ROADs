# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/My\ Drive/FinalProject/
# Out:
# /content/drive/My Drive/FinalProject

# %% [markdown]
# # YOLO_V8 model load

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
from ultralytics import YOLO
import cv2
model = YOLO("yolov8s.pt")

# %% [markdown]
# # Real-time detecting using webcam

# %%
# webcam 연결
cap = cv2.VideoCapture(0)

while cap.isOpened():
    success, image = cap.read()     # 1개 frame을 image로 읽는다.
    if not success:
        print("Ignoring empty camera frame.")
        # If loading a video, use 'break' instead of 'continue'.
        break

    # To improve performance
    frame = cv2.flip(image, 1)
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # inference result
    result = model(img,
                   conf = 0.5,        # 'inference prob > 0.5'인 것만 결과로 return
                   verbose = False)   # 추론 결과 로그를 출력하지 않음

    # 결과에서 위치, 클래스 정보 추출
    xyxy_list = result.boxes.xyxy.to('cpu').numpy().astype('int32')
    cls_list = result.boxes.cls.to('cpu').numpy().astype('int32')
    conf_list = result.boxes.conf.to('cpu').numpy()

    # for in 문을 이용해 찾은 object 별로 bbox 처리를 한다.
    for xyxy, cls, conf in zip(xyxy_list, cls_list, conf_list):
        pt1, pt2 = xyxy[:2], xyxy[2:]
        txt = f'{result.names[cls]} - {conf*100:.3f}%'
        # box
        cv2.rectangle(frame, pt1, pt2, color=(255,0,0), thickness=2)
        cv2.putText(frame, txt, org=pt1, fontFace=cv2.FONT_HERSHEY_COMPLEX, fontScale=0.5,
                    color=(200,0,0), thickness=1, lineType=cv2.LINE_AA)

    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()             # 웹캠연결 종료
cv2.destroyAllWindows()   # 출력 윈도우 종료

# %% [markdown]
# # Dataset pre-processing for YOLO Model

# %%
##### 사용안함 #####
label = ['PE드럼 정상', 'PE드럼 파손', 'PE안내봉 정상', 'PE안내봉 파손', '라바콘 정상', '라바콘 파손',
         '시선유도봉 정상', '시선유도봉 파손', '제설함 정상', '제설함 파손','PE입간판 정상', 'PE입간판 파손',
         'PE휀스 정상', 'PE휀스 파손', 'PE방호벽 정상', 'PE방호벽 파손']

label_dict = {label_name: idx for idx, label_name in enumerate(label)}

# %%
import glob
import json
import pandas as pd

json_file_path = '/content/drive/MyDrive/FinalProject/dataset/real_sunny_AM_20220614_112456_sedan_Dong-gu_00026.json'
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)

# %%
# 'images'에서 'width', 'height', 'file_name' 추출
image_data = [{'width': img['width'],
               'height': img['height'],
               'file_name': img['file_name']} for img in data['images']]

# 'annotations'에서 'category_id', 'bbox' 추출
annotation_data = [{'category_id': ann['category_id'],
                    'bbox': ann['bbox']} for ann in data['annotations']]

df_images = pd.DataFrame(image_data)
df_annotations = pd.DataFrame(annotation_data)

df_images
# Out:
#    width  height                                          file_name
# 0   1920    1080  real_sunny_AM_20220614_112456_sedan_Dong-gu_00...

# %%
df_annotations
# Out:
#    category_id                              bbox
# 0            9   [545.07, 216.31, 56.87, 208.71]
# 1            9  [167.11, 382.08, 132.67, 411.91]
# 2            9   [669.23, 156.16, 37.19, 149.74]
# 3            9   [409.57, 274.31, 78.65, 282.04]
# 4           12    [153.92, 185.8, 288.22, 139.0]

# %% [markdown]
# ### 여러 .json 파일에서 한번에 .txt 추출하기

# %%
# bbox 좌표: 좌상단 x, 좌상단 y, bbox의 W, box의 H
def convert_to_yolov8_format(bbox, image_width, image_height):
    x_center = (bbox[0] + bbox[2] / 2) / image_width
    y_center = (bbox[1] + bbox[3] / 2) / image_height
    width = bbox[2] / image_width
    height = bbox[3] / image_height

    return x_center, y_center, width, height

# %%
dst_dir = '/content/drive/MyDrive/FinalProject'
dataset_dir = '/content/drive/MyDrive/FinalProject/dataset'

# Iterate through all JSON files in the dataset directory
for json_file in os.listdir(dataset_dir):
    if json_file.endswith('.json'):
        json_path = os.path.join(dataset_dir, json_file)
        print(len(json_path))      # print

        with open(json_path, 'r') as f:
            data = json.load(f)

        # Process each annotation in the JSON file
        for annotation in data.get('annotations', []):
            label_path = os.path.join(dst_dir, "labels")

            if not os.path.exists(label_path):
                os.makedirs(label_path)

            image_name = data['images'][0]['file_name'].split('.')[0]
            print(f'image_name: {image_name}')

            image_width = data['images'][0]['width']
            image_height = data['images'][0]['height']
            print(f'image_width: {image_width}, image_height: {image_height}')

            label = annotation.get('category_id', None)
            bbox = annotation.get('bbox', None)
            print(f'label: {label}, bbox: {bbox}')

            if label is not None and bbox is not None:
                x_center, y_center, width, height = convert_to_yolov8_format(bbox=bbox,
                                                                             image_width=image_width,
                                                                             image_height=image_height)

                x_center = format(x_center, '.6f')
                y_center = format(y_center, '.6f')
                width = format(width, '.6f')
                height = format(height, '.6f')

                arr = list(map(str, [label, x_center, y_center, width, height]))
                data_line = ' '.join(arr) + '\n'

                # Save the data to a text file
                txt_filename = os.path.join(label_path, f"{image_name}.txt")
                with open(txt_filename, 'a', encoding='UTF-8') as txt_file:
                    txt_file.write(data_line)

# %%
eg = '/content/drive/MyDrive/FinalProject/labels/real_sunny_AM_20220614_112456_sedan_Dong-gu_00026.txt'

with open(eg, 'r', encoding='UTF-8') as file:
    content = file.read()

# (label, x_center, y_center, w, h) 순서로 데이터가 들어가 있는 것 확인!
print(content)
# Out:
# 9 0.298701 0.296912 0.029620 0.193250
# 9 0.121586 0.544477 0.069099 0.381398
# 9 0.358242 0.213917 0.019370 0.138648
# 9 0.233799 0.384565 0.040964 0.261148
# 12 0.155224 0.236389 0.150115 0.128704

# %% [markdown]
# ### AI hub dataset(.json) load - reference

# %%
import xmltodict

#label_dict
label = ['bicycle', 'bus', 'car', 'carrier', 'cat', 'dog', 'motorcycle',
        'movable_signage', 'person', 'scooter', 'stroller', 'truck', 'wheelchair',
        'barricade', 'bench', 'bollard', 'chair', 'fire_hydrant', 'kiosk', 'parking_meter',
        'pole', 'potted_plant', 'power_controller', 'stop', 'table', 'traffic_light',
        'traffic_light_controller', 'traffic_sign', 'tree_trunk']
label_dict = { label_name: idx for idx, label_name in enumerate(label)}

# %%
# reference data 확인
xml_path = '/content/drive/MyDrive/FinalProject/bbox_sample.xml'
with open(xml_path, 'rt', encoding="UTF-8") as f:
  doc = xmltodict.parse(f.read())

json_data = json.loads(json.dumps(doc))

# %%
json_data
# Out:
# {'annotations': {'version': '1.1',
#   'meta': {'task': {'id': '1068',
#     'name': 'bbox_sample',
#     'size': '300',
#     'mode': 'annotation',
#     'overlap': '0',
#     'bugtracker': None,
#     'flipped': 'False',
#     'created': '2019-08-20 07:51:38.306862+03:00',
#     'updated': '2019-09-18 12:26:30.562392+03:00',
#     'start_frame': '0',
#     'stop_frame': '0',
#     'frame_filter': '0',
#     'labels': {'label': [{'name': 'traffic_light_controller',
#        'attributes': None},
#       {'name': 'power_controller', 'attributes': None},
#       {'name': 'wheelchair', 'attributes': None},
#       {'name': 'truck', 'attributes': None},
#       {'name': 'tree_trunk', 'attributes': None},
#       {'name': 'traffic_sign', 'attributes': None},
#       {'name': 'traffic_light', 'attributes': None},
#       {'name': 'table', 'attributes': None},
#       {'name': 'stroller', 'attributes': None},
#       {'name': 'stop', 'attributes': None},
#       {'name': 'scooter', 'attributes': None},
#       {'name': 'potted_plant', 'attributes': None},
#       {'name': 'pole', 'attributes': None},
#       {'name': 'person', 'attributes': None},
#       {'name': 'parking_meter', 'attributes': None},
#       {'name': 'movable_signage', 'attributes': None},
#       {'name': 'motorcycle', 'attributes': None},
#       {'name': 'kiosk', 'attributes': None},
#       {'name': 'fire_hydrant', 'attributes': None},
#       {'name': 'dog', 'attributes': None},
#       {'name': 'chair', 'attributes': None},
#       {'name': 'cat', 'attributes': None},
#       {'name': 'carrier', 'attributes': None},
#       {'name': 'car', 'attributes': None},
#       {'name': 'bus', 'attributes': None},
#       {'name': 'bollard', 'attributes': None},
#       {'name': 'bicycle', 'attributes': None},
#       {'name': 'bench', 'attributes': None},
#       {'name': 'barricade', 'attributes': None}]},
#     'segments': {'segment': {'id': '1007',
#       'start': '0',
#       'stop': '299',
#       'url': 'http://112.169.146.227:8080/?id=1007'}},
#     'owner': {'username': 'aiadmin', 'email': 'aiadmin@testworks.co.kr'}},
#    'dumped': '2019-09-20 03:33:20.452759+03:00'},
#   'image': [{'@id': '0',
#     '@name': 'MP_SEL_B027451.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '0.00',
#       '@ytl': '731.65',
#       '@xbr': '175.30',
#       '@ybr': '1009.50',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '0',
#       '@xtl': '309.31',
#       '@ytl': '370.40',
#       '@xbr': '794.50',
#       '@ybr': '711.40',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '0',
#       '@xtl': '1431.86',
#       '@ytl': '432.81',
#       '@xbr': '1799.30',
#       '@ybr': '686.00',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '837.00',
#       '@ytl': '422.17',
#       '@xbr': '908.60',
#       '@ybr': '627.40',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '1227.67',
#       '@ytl': '463.17',
#       '@xbr': '1246.98',
#       '@ybr': '519.53',
#       '@z_order': '5'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '934.66',
#       '@ytl': '449.40',
#       '@xbr': '1171.60',
#       '@ybr': '528.80',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '1',
#       '@xtl': '1349.10',
#       '@ytl': '428.82',
#       '@xbr': '1613.70',
#       '@ybr': '660.40',
#       '@z_order': '4'}]},
#    {'@id': '1',
#     '@name': 'MP_SEL_B027452.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '949.52',
#       '@ytl': '381.12',
#       '@xbr': '1154.20',
#       '@ybr': '498.70',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1219.00',
#       '@ytl': '368.22',
#       '@xbr': '1475.00',
#       '@ybr': '530.40',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '1',
#       '@xtl': '618.19',
#       '@ytl': '386.73',
#       '@xbr': '656.01',
#       '@ybr': '480.74',
#       '@z_order': '4'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1000.66',
#       '@ytl': '400.90',
#       '@xbr': '1049.40',
#       '@ybr': '568.50',
#       '@z_order': '0'},
#      {'@label': 'kiosk',
#       '@occluded': '1',
#       '@xtl': '1236.43',
#       '@ytl': '353.67',
#       '@xbr': '1327.73',
#       '@ybr': '488.31',
#       '@z_order': '5'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '168.79',
#       '@ytl': '500.43',
#       '@xbr': '383.70',
#       '@ybr': '801.00',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '500.50',
#       '@ytl': '447.39',
#       '@xbr': '556.80',
#       '@ybr': '560.80',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '1016.62',
#       '@ytl': '327.90',
#       '@xbr': '1218.10',
#       '@ybr': '530.80',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '805.37',
#       '@ytl': '407.44',
#       '@xbr': '823.20',
#       '@ybr': '463.50',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1188.30',
#       '@ytl': '454.75',
#       '@xbr': '1246.20',
#       '@ybr': '573.60',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1207.00',
#       '@ytl': '307.00',
#       '@xbr': '1246.70',
#       '@ybr': '526.70',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '1',
#       '@xtl': '1111.77',
#       '@ytl': '469.39',
#       '@xbr': '1153.70',
#       '@ybr': '537.80',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '884.42',
#       '@ytl': '410.04',
#       '@xbr': '898.60',
#       '@ybr': '447.20',
#       '@z_order': '3'},
#      {'@label': 'bicycle',
#       '@occluded': '0',
#       '@xtl': '569.73',
#       '@ytl': '449.92',
#       '@xbr': '615.64',
#       '@ybr': '534.84',
#       '@z_order': '2'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '561.40',
#       '@ytl': '56.00',
#       '@xbr': '621.73',
#       '@ybr': '531.61',
#       '@z_order': '1'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1435.40',
#       '@ytl': '368.30',
#       '@xbr': '1920.00',
#       '@ybr': '761.20',
#       '@z_order': '0'}]},
#    {'@id': '2',
#     '@name': 'MP_SEL_B027453.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1899.40',
#       '@ytl': '410.95',
#       '@xbr': '1920.00',
#       '@ybr': '562.00',
#       '@z_order': '2'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1046.10',
#       '@ytl': '348.17',
#       '@xbr': '1184.70',
#       '@ybr': '780.30',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '993.47',
#       '@ytl': '397.21',
#       '@xbr': '1019.00',
#       '@ybr': '469.10',
#       '@z_order': '1'},
#      {'@label': 'motorcycle',
#       '@occluded': '1',
#       '@xtl': '1440.27',
#       '@ytl': '429.98',
#       '@xbr': '1490.90',
#       '@ybr': '502.80',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '949.37',
#       '@ytl': '410.00',
#       '@xbr': '1021.20',
#       '@ybr': '722.30',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1170.46',
#       '@ytl': '386.21',
#       '@xbr': '1226.90',
#       '@ybr': '562.80',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1245.60',
#       '@ytl': '0.00',
#       '@xbr': '1375.63',
#       '@ybr': '773.60',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '1',
#       '@xtl': '1883.59',
#       '@ytl': '326.50',
#       '@xbr': '1920.00',
#       '@ybr': '507.17',
#       '@z_order': '3'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1297.70',
#       '@ytl': '384.33',
#       '@xbr': '1453.50',
#       '@ybr': '516.70',
#       '@z_order': '0'}]},
#    {'@id': '3',
#     '@name': 'MP_SEL_B027454.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '943.56',
#       '@ytl': '261.66',
#       '@xbr': '1097.40',
#       '@ybr': '714.60',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '691.00',
#       '@ytl': '0.00',
#       '@xbr': '771.00',
#       '@ybr': '638.20',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '813.75',
#       '@ytl': '263.81',
#       '@xbr': '935.90',
#       '@ybr': '575.00',
#       '@z_order': '0'},
#      {'@label': 'bus',
#       '@occluded': '1',
#       '@xtl': '302.90',
#       '@ytl': '229.20',
#       '@xbr': '496.20',
#       '@ybr': '347.60',
#       '@z_order': '0'}]},
#    {'@id': '4',
#     '@name': 'MP_SEL_B027455.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1071.20',
#       '@ytl': '491.45',
#       '@xbr': '1229.20',
#       '@ybr': '574.50',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '1',
#       '@xtl': '1442.31',
#       '@ytl': '669.10',
#       '@xbr': '1515.67',
#       '@ybr': '804.60',
#       '@z_order': '0'},
#      {'@label': 'chair',
#       '@occluded': '0',
#       '@xtl': '1212.08',
#       '@ytl': '527.26',
#       '@xbr': '1265.90',
#       '@ybr': '600.80',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '0',
#       '@xtl': '357.08',
#       '@ytl': '155.89',
#       '@xbr': '390.08',
#       '@ybr': '730.50',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '597.00',
#       '@ytl': '0.00',
#       '@xbr': '662.00',
#       '@ybr': '644.10',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '958.50',
#       '@ytl': '0.00',
#       '@xbr': '1001.19',
#       '@ybr': '572.30',
#       '@z_order': '0'},
#      {'@label': 'bicycle',
#       '@occluded': '0',
#       '@xtl': '983.29',
#       '@ytl': '507.90',
#       '@xbr': '1037.70',
#       '@ybr': '575.00',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '668.28',
#       '@ytl': '477.77',
#       '@xbr': '835.30',
#       '@ybr': '602.50',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '650.36',
#       '@ytl': '473.75',
#       '@xbr': '746.90',
#       '@ybr': '555.00',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '893.74',
#       '@ytl': '510.26',
#       '@xbr': '929.75',
#       '@ybr': '550.25',
#       '@z_order': '2'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '934.56',
#       '@ytl': '513.15',
#       '@xbr': '968.56',
#       '@ybr': '555.23',
#       '@z_order': '3'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '23.37',
#       '@ytl': '512.17',
#       '@xbr': '235.20',
#       '@ybr': '736.70',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1642.04',
#       '@ytl': '718.84',
#       '@xbr': '1730.80',
#       '@ybr': '903.30',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '1',
#       '@xtl': '1327.48',
#       '@ytl': '634.27',
#       '@xbr': '1382.90',
#       '@ybr': '750.40',
#       '@z_order': '0'}]},
#    {'@id': '5',
#     '@name': 'MP_SEL_B027456.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '732.20',
#       '@ytl': '438.60',
#       '@xbr': '846.20',
#       '@ybr': '541.40',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '632.19',
#       '@ytl': '420.08',
#       '@xbr': '742.40',
#       '@ybr': '765.20',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1051.91',
#       '@ytl': '443.82',
#       '@xbr': '1076.80',
#       '@ybr': '515.40',
#       '@z_order': '2'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1704.24',
#       '@ytl': '506.12',
#       '@xbr': '1920.00',
#       '@ybr': '696.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '691.30',
#       '@ytl': '452.06',
#       '@xbr': '832.30',
#       '@ybr': '562.10',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1014.07',
#       '@ytl': '446.15',
#       '@xbr': '1031.70',
#       '@ybr': '506.20',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1647.30',
#       '@ytl': '458.22',
#       '@xbr': '1765.10',
#       '@ybr': '723.90',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '1017.69',
#       '@ytl': '459.29',
#       '@xbr': '1544.80',
#       '@ybr': '637.90',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '19.60',
#       '@ytl': '221.50',
#       '@xbr': '82.80',
#       '@ybr': '1080.00',
#       '@z_order': '7'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '861.80',
#       '@ytl': '419.64',
#       '@xbr': '956.30',
#       '@ybr': '682.50',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '997.15',
#       '@ytl': '444.73',
#       '@xbr': '1011.31',
#       '@ybr': '491.66',
#       '@z_order': '1'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1088.91',
#       '@ytl': '453.70',
#       '@xbr': '1252.50',
#       '@ybr': '509.70',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '694.98',
#       '@ytl': '0.00',
#       '@xbr': '719.58',
#       '@ybr': '625.40',
#       '@z_order': '4'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '968.04',
#       '@ytl': '449.97',
#       '@xbr': '1012.66',
#       '@ybr': '480.57',
#       '@z_order': '3'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1485.64',
#       '@ytl': '447.32',
#       '@xbr': '1920.00',
#       '@ybr': '602.00',
#       '@z_order': '0'}]},
#    {'@id': '6',
#     '@name': 'MP_SEL_B027457.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'potted_plant',
#       '@occluded': '0',
#       '@xtl': '1277.39',
#       '@ytl': '321.56',
#       '@xbr': '1319.80',
#       '@ybr': '427.80',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1015.47',
#       '@ytl': '239.16',
#       '@xbr': '1068.10',
#       '@ybr': '390.10',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '907.60',
#       '@ytl': '218.64',
#       '@xbr': '984.50',
#       '@ybr': '441.80',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '147.00',
#       '@ytl': '0.00',
#       '@xbr': '330.40',
#       '@ybr': '1041.60',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1228.00',
#       '@ytl': '0.00',
#       '@xbr': '1263.00',
#       '@ybr': '508.50',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '769.00',
#       '@ytl': '0.00',
#       '@xbr': '808.00',
#       '@ybr': '471.00',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1157.00',
#       '@ytl': '0.00',
#       '@xbr': '1196.00',
#       '@ybr': '443.00',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '831.00',
#       '@ytl': '0.00',
#       '@xbr': '879.90',
#       '@ybr': '395.40',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '672.19',
#       '@ytl': '0.00',
#       '@xbr': '759.60',
#       '@ybr': '509.40',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '416.80',
#       '@ytl': '0.00',
#       '@xbr': '564.10',
#       '@ybr': '726.80',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '1',
#       '@xtl': '1050.94',
#       '@ytl': '183.49',
#       '@xbr': '1097.70',
#       '@ybr': '345.20',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '212.76',
#       '@ytl': '186.48',
#       '@xbr': '430.10',
#       '@ybr': '346.18',
#       '@z_order': '1'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '535.24',
#       '@ytl': '255.59',
#       '@xbr': '661.90',
#       '@ybr': '331.90',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '382.58',
#       '@ytl': '238.35',
#       '@xbr': '568.40',
#       '@ybr': '357.40',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '83.00',
#       '@ytl': '263.76',
#       '@xbr': '278.30',
#       '@ybr': '352.60',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '522.76',
#       '@ytl': '60.58',
#       '@xbr': '570.20',
#       '@ybr': '76.60',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '791.83',
#       '@ytl': '253.00',
#       '@xbr': '921.70',
#       '@ybr': '308.40',
#       '@z_order': '0'}]},
#    {'@id': '7',
#     '@name': 'MP_SEL_B027458.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '622.37',
#       '@ytl': '324.00',
#       '@xbr': '687.90',
#       '@ybr': '378.70',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '663.30',
#       '@ytl': '333.89',
#       '@xbr': '717.10',
#       '@ybr': '377.10',
#       '@z_order': '1'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '973.85',
#       '@ytl': '356.69',
#       '@xbr': '1329.80',
#       '@ybr': '460.90',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '479.61',
#       '@ytl': '308.21',
#       '@xbr': '599.10',
#       '@ybr': '400.20',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '60.39',
#       '@ytl': '271.00',
#       '@xbr': '341.20',
#       '@ybr': '489.40',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1074.32',
#       '@ytl': '0.00',
#       '@xbr': '1138.32',
#       '@ybr': '485.85',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '723.85',
#       '@ytl': '332.36',
#       '@xbr': '890.80',
#       '@ybr': '445.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '207.08',
#       '@xbr': '193.70',
#       '@ybr': '563.50',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '332.20',
#       '@ytl': '315.47',
#       '@xbr': '515.40',
#       '@ybr': '427.90',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '857.06',
#       '@ytl': '331.50',
#       '@xbr': '885.30',
#       '@ybr': '406.60',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1388.76',
#       '@ytl': '357.00',
#       '@xbr': '1580.90',
#       '@ybr': '809.10',
#       '@z_order': '0'}]},
#    {'@id': '8',
#     '@name': 'MP_SEL_B027459.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'pole',
#       '@occluded': '0',
#       '@xtl': '627.24',
#       '@ytl': '222.00',
#       '@xbr': '647.50',
#       '@ybr': '585.94',
#       '@z_order': '1'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '597.30',
#       '@ytl': '0.00',
#       '@xbr': '627.60',
#       '@ybr': '589.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '251.95',
#       '@xbr': '164.70',
#       '@ybr': '977.40',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '615.00',
#       '@ytl': '478.53',
#       '@xbr': '727.60',
#       '@ybr': '576.80',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '0',
#       '@xtl': '1001.29',
#       '@ytl': '516.43',
#       '@xbr': '1084.80',
#       '@ybr': '608.60',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '1',
#       '@xtl': '973.78',
#       '@ytl': '495.78',
#       '@xbr': '1026.60',
#       '@ybr': '590.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '885.12',
#       '@ytl': '535.06',
#       '@xbr': '919.90',
#       '@ybr': '560.40',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '690.60',
#       '@ytl': '521.02',
#       '@xbr': '793.50',
#       '@ybr': '567.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '295.50',
#       '@xbr': '555.20',
#       '@ybr': '746.10',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '775.75',
#       '@ytl': '518.74',
#       '@xbr': '831.70',
#       '@ybr': '564.00',
#       '@z_order': '0'}]},
#    {'@id': '9',
#     '@name': 'MP_SEL_B027460.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '1800.48',
#       '@ytl': '187.24',
#       '@xbr': '1859.20',
#       '@ybr': '215.40',
#       '@z_order': '1'},
#      {'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '1857.67',
#       '@ytl': '177.27',
#       '@xbr': '1909.10',
#       '@ybr': '228.20',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1400.81',
#       '@ytl': '462.70',
#       '@xbr': '1407.99',
#       '@ybr': '500.21',
#       '@z_order': '3'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1439.44',
#       '@ytl': '470.26',
#       '@xbr': '1446.23',
#       '@ybr': '507.74',
#       '@z_order': '2'},
#      {'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '1195.10',
#       '@ytl': '0.00',
#       '@xbr': '1425.90',
#       '@ybr': '237.90',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '1463.94',
#       '@ytl': '386.60',
#       '@xbr': '1908.60',
#       '@ybr': '635.70',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '1135.88',
#       '@ytl': '481.90',
#       '@xbr': '1183.70',
#       '@ybr': '646.30',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '796.44',
#       '@ytl': '386.04',
#       '@xbr': '823.20',
#       '@ybr': '513.00',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1327.00',
#       '@ytl': '2.00',
#       '@xbr': '1387.20',
#       '@ybr': '797.10',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '0',
#       '@xtl': '538.08',
#       '@ytl': '403.53',
#       '@xbr': '621.40',
#       '@ybr': '662.90',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1550.70',
#       '@ytl': '0.00',
#       '@xbr': '1748.58',
#       '@ybr': '1003.20',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '855.04',
#       '@ytl': '405.77',
#       '@xbr': '902.40',
#       '@ybr': '532.20',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '0',
#       '@xtl': '954.49',
#       '@ytl': '431.24',
#       '@xbr': '1052.60',
#       '@ybr': '576.00',
#       '@z_order': '0'}]},
#    {'@id': '10',
#     '@name': 'MP_SEL_B027461.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '971.40',
#       '@ytl': '0.00',
#       '@xbr': '1037.90',
#       '@ybr': '663.90',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '1',
#       '@xtl': '1780.42',
#       '@ytl': '572.28',
#       '@xbr': '1800.52',
#       '@ybr': '603.88',
#       '@z_order': '9'},
#      {'@label': 'fire_hydrant',
#       '@occluded': '0',
#       '@xtl': '1849.42',
#       '@ytl': '593.01',
#       '@xbr': '1867.35',
#       '@ybr': '635.38',
#       '@z_order': '8'},
#      {'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '1224.30',
#       '@ytl': '400.78',
#       '@xbr': '1262.55',
#       '@ybr': '426.79',
#       '@z_order': '7'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '1702.90',
#       '@ytl': '415.18',
#       '@xbr': '1732.50',
#       '@ybr': '614.80',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1811.88',
#       '@ytl': '560.50',
#       '@xbr': '1843.33',
#       '@ybr': '605.77',
#       '@z_order': '6'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1766.82',
#       '@ytl': '571.55',
#       '@xbr': '1782.34',
#       '@ybr': '604.07',
#       '@z_order': '5'},
#      {'@label': 'bollard',
#       '@occluded': '1',
#       '@xtl': '1758.11',
#       '@ytl': '570.70',
#       '@xbr': '1772.99',
#       '@ybr': '603.43',
#       '@z_order': '4'},
#      {'@label': 'truck',
#       '@occluded': '0',
#       '@xtl': '1202.82',
#       '@ytl': '494.06',
#       '@xbr': '1275.00',
#       '@ybr': '560.00',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '1303.55',
#       '@ytl': '525.53',
#       '@xbr': '1386.40',
#       '@ybr': '579.30',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '940.20',
#       '@ytl': '129.80',
#       '@xbr': '996.90',
#       '@ybr': '637.90',
#       '@z_order': '2'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1361.00',
#       '@ytl': '0.00',
#       '@xbr': '1679.00',
#       '@ybr': '1080.00',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '979.71',
#       '@ytl': '139.00',
#       '@xbr': '1094.00',
#       '@ybr': '748.77',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '1',
#       '@xtl': '912.74',
#       '@ytl': '536.21',
#       '@xbr': '974.30',
#       '@ybr': '594.50',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '861.13',
#       '@ytl': '495.12',
#       '@xbr': '893.00',
#       '@ybr': '556.60',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '823.60',
#       '@ytl': '480.57',
#       '@xbr': '841.70',
#       '@ybr': '558.40',
#       '@z_order': '0'},
#      {'@label': 'traffic_light_controller',
#       '@occluded': '0',
#       '@xtl': '969.10',
#       '@ytl': '275.74',
#       '@xbr': '1043.66',
#       '@ybr': '416.40',
#       '@z_order': '1'}]},
#    {'@id': '11',
#     '@name': 'MP_SEL_B027462.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '265.90',
#       '@ytl': '383.50',
#       '@xbr': '461.40',
#       '@ybr': '488.20',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1037.70',
#       '@ytl': '0.00',
#       '@xbr': '1067.50',
#       '@ybr': '541.40',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '561.50',
#       '@ytl': '0.00',
#       '@xbr': '689.00',
#       '@ybr': '694.00',
#       '@z_order': '0'},
#      {'@label': 'traffic_sign',
#       '@occluded': '0',
#       '@xtl': '405.06',
#       '@ytl': '311.24',
#       '@xbr': '436.00',
#       '@ybr': '365.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1063.41',
#       '@ytl': '425.46',
#       '@xbr': '1249.40',
#       '@ybr': '556.10',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '655.19',
#       '@ytl': '269.12',
#       '@xbr': '688.40',
#       '@ybr': '282.40',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '717.00',
#       '@ytl': '0.00',
#       '@xbr': '752.20',
#       '@ybr': '588.80',
#       '@z_order': '0'},
#      {'@label': 'fire_hydrant',
#       '@occluded': '0',
#       '@xtl': '701.84',
#       '@ytl': '512.67',
#       '@xbr': '730.90',
#       '@ybr': '602.90',
#       '@z_order': '0'},
#      {'@label': 'bus',
#       '@occluded': '1',
#       '@xtl': '445.18',
#       '@ytl': '334.06',
#       '@xbr': '890.40',
#       '@ybr': '474.70',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '805.60',
#       '@ytl': '220.34',
#       '@xbr': '828.30',
#       '@ybr': '316.80',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '0.24',
#       '@ytl': '241.33',
#       '@xbr': '285.60',
#       '@ybr': '602.50',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '726.71',
#       '@ytl': '260.72',
#       '@xbr': '784.40',
#       '@ybr': '565.90',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '1280.65',
#       '@ytl': '247.31',
#       '@xbr': '1459.00',
#       '@ybr': '758.60',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '141.65',
#       '@ytl': '211.34',
#       '@xbr': '177.75',
#       '@ybr': '226.24',
#       '@z_order': '1'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '205.05',
#       '@ytl': '222.94',
#       '@xbr': '237.35',
#       '@ybr': '238.34',
#       '@z_order': '2'}]},
#    {'@id': '12',
#     '@name': 'MP_SEL_B027463.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '760.19',
#       '@ytl': '0.00',
#       '@xbr': '808.50',
#       '@ybr': '442.35',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '1312.35',
#       '@ytl': '215.71',
#       '@xbr': '1832.20',
#       '@ybr': '548.80',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1106.92',
#       '@ytl': '280.89',
#       '@xbr': '1160.70',
#       '@ybr': '441.50',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '1604.46',
#       '@ytl': '405.35',
#       '@xbr': '1735.07',
#       '@ybr': '602.60',
#       '@z_order': '2'},
#      {'@label': 'movable_signage',
#       '@occluded': '1',
#       '@xtl': '1259.69',
#       '@ytl': '257.42',
#       '@xbr': '1335.28',
#       '@ybr': '417.47',
#       '@z_order': '1'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1117.41',
#       '@ytl': '277.13',
#       '@xbr': '1260.22',
#       '@ybr': '374.47',
#       '@z_order': '3'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '792.76',
#       '@ytl': '286.50',
#       '@xbr': '978.50',
#       '@ybr': '437.20',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1742.91',
#       '@ytl': '331.06',
#       '@xbr': '1920.00',
#       '@ybr': '655.80',
#       '@z_order': '0'}]},
#    {'@id': '13',
#     '@name': 'MP_SEL_B027464.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'pole',
#       '@occluded': '0',
#       '@xtl': '1505.50',
#       '@ytl': '26.30',
#       '@xbr': '1627.52',
#       '@ybr': '768.70',
#       '@z_order': '5'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1102.39',
#       '@ytl': '395.32',
#       '@xbr': '1414.60',
#       '@ybr': '570.70',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '0',
#       '@xtl': '1815.00',
#       '@ytl': '416.76',
#       '@xbr': '1919.76',
#       '@ybr': '515.00',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '0',
#       '@xtl': '1730.03',
#       '@ytl': '414.20',
#       '@xbr': '1824.20',
#       '@ybr': '502.80',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1724.40',
#       '@ytl': '0.00',
#       '@xbr': '1776.70',
#       '@ybr': '481.60',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '1035.65',
#       '@ytl': '381.00',
#       '@xbr': '1113.40',
#       '@ybr': '434.60',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '0',
#       '@xtl': '971.57',
#       '@ytl': '435.06',
#       '@xbr': '1011.97',
#       '@ybr': '550.13',
#       '@z_order': '3'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '733.42',
#       '@ytl': '365.78',
#       '@xbr': '765.70',
#       '@ybr': '438.50',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1252.40',
#       '@ytl': '0.00',
#       '@xbr': '1371.70',
#       '@ybr': '704.50',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '961.00',
#       '@ytl': '132.00',
#       '@xbr': '1014.10',
#       '@ybr': '546.00',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '888.60',
#       '@ytl': '256.36',
#       '@xbr': '940.60',
#       '@ybr': '486.00',
#       '@z_order': '0'},
#      {'@label': 'traffic_sign',
#       '@occluded': '0',
#       '@xtl': '1521.29',
#       '@ytl': '0.00',
#       '@xbr': '1695.20',
#       '@ybr': '191.80',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1433.69',
#       '@ytl': '395.53',
#       '@xbr': '1700.80',
#       '@ybr': '507.40',
#       '@z_order': '0'}]},
#    {'@id': '14',
#     '@name': 'MP_SEL_B027465.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '909.60',
#       '@ytl': '389.87',
#       '@xbr': '1014.71',
#       '@ybr': '522.99',
#       '@z_order': '2'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '628.70',
#       '@ytl': '0.00',
#       '@xbr': '663.80',
#       '@ybr': '645.70',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '1826.19',
#       '@ytl': '639.81',
#       '@xbr': '1920.00',
#       '@ybr': '894.20',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '0',
#       '@xtl': '959.04',
#       '@ytl': '415.20',
#       '@xbr': '1017.80',
#       '@ybr': '535.30',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1436.00',
#       '@ytl': '0.00',
#       '@xbr': '1499.40',
#       '@ybr': '686.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1276.69',
#       '@ytl': '449.53',
#       '@xbr': '1443.80',
#       '@ybr': '547.80',
#       '@z_order': '0'}]},
#    {'@id': '15',
#     '@name': 'MP_SEL_B027466.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '998.70',
#       '@ytl': '0.00',
#       '@xbr': '1049.90',
#       '@ybr': '590.40',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1143.83',
#       '@ytl': '441.00',
#       '@xbr': '1295.10',
#       '@ybr': '540.70',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1442.16',
#       '@ytl': '0.00',
#       '@xbr': '1609.20',
#       '@ybr': '1080.00',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1017.40',
#       '@ytl': '0.00',
#       '@xbr': '1278.20',
#       '@ybr': '802.70',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1573.37',
#       '@ytl': '435.37',
#       '@xbr': '1700.10',
#       '@ybr': '502.40',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '897.85',
#       '@ytl': '419.91',
#       '@xbr': '931.50',
#       '@ybr': '504.90',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '249.58',
#       '@xbr': '526.10',
#       '@ybr': '1079.20',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '1683.63',
#       '@ytl': '306.68',
#       '@xbr': '1919.63',
#       '@ybr': '636.80',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '972.80',
#       '@ytl': '265.80',
#       '@xbr': '1010.20',
#       '@ybr': '522.30',
#       '@z_order': '0'}]},
#    {'@id': '16',
#     '@name': 'MP_SEL_B027467.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '955.74',
#       '@ytl': '426.83',
#       '@xbr': '989.50',
#       '@ybr': '517.10',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '794.98',
#       '@ytl': '410.10',
#       '@xbr': '866.20',
#       '@ybr': '471.80',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '671.06',
#       '@ytl': '375.70',
#       '@xbr': '747.80',
#       '@ybr': '596.80',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '609.76',
#       '@ytl': '414.33',
#       '@xbr': '801.10',
#       '@ybr': '486.40',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '0.00',
#       '@ytl': '344.67',
#       '@xbr': '584.00',
#       '@ybr': '680.90',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '519.71',
#       '@ytl': '407.70',
#       '@xbr': '745.40',
#       '@ybr': '547.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1045.47',
#       '@ytl': '299.58',
#       '@xbr': '1920.00',
#       '@ybr': '926.10',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '679.15',
#       '@ytl': '0.00',
#       '@xbr': '704.40',
#       '@ybr': '515.50',
#       '@z_order': '2'}]},
#    {'@id': '17',
#     '@name': 'MP_SEL_B027468.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '1084.36',
#       '@ytl': '397.60',
#       '@xbr': '1105.10',
#       '@ybr': '460.00',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '830.00',
#       '@ytl': '46.21',
#       '@xbr': '894.50',
#       '@ybr': '548.20',
#       '@z_order': '1'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '913.10',
#       '@ytl': '218.72',
#       '@xbr': '947.40',
#       '@ybr': '523.30',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1434.90',
#       '@ytl': '0.00',
#       '@xbr': '1517.00',
#       '@ybr': '591.40',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '648.80',
#       '@ytl': '219.37',
#       '@xbr': '700.00',
#       '@ybr': '234.50',
#       '@z_order': '0'},
#      {'@label': 'traffic_sign',
#       '@occluded': '0',
#       '@xtl': '741.45',
#       '@ytl': '48.92',
#       '@xbr': '858.20',
#       '@ybr': '187.30',
#       '@z_order': '0'},
#      {'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '897.48',
#       '@ytl': '54.37',
#       '@xbr': '987.00',
#       '@ybr': '155.30',
#       '@z_order': '0'},
#      {'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '741.63',
#       '@ytl': '0.00',
#       '@xbr': '862.40',
#       '@ybr': '45.90',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '1138.88',
#       '@ytl': '387.94',
#       '@xbr': '1158.20',
#       '@ybr': '443.20',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1101.45',
#       '@ytl': '386.36',
#       '@xbr': '1129.40',
#       '@ybr': '459.70',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '950.60',
#       '@ytl': '0.00',
#       '@xbr': '1000.20',
#       '@ybr': '510.10',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '471.10',
#       '@ytl': '0.00',
#       '@xbr': '631.70',
#       '@ybr': '844.60',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '1571.06',
#       '@ytl': '425.41',
#       '@xbr': '1668.20',
#       '@ybr': '550.60',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '655.57',
#       '@ytl': '359.00',
#       '@xbr': '855.00',
#       '@ybr': '499.20',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '1332.00',
#       '@ytl': '151.40',
#       '@xbr': '1387.10',
#       '@ybr': '537.20',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '770.48',
#       '@ytl': '0.00',
#       '@xbr': '834.48',
#       '@ybr': '604.06',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1719.10',
#       '@ytl': '0.00',
#       '@xbr': '1850.00',
#       '@ybr': '745.80',
#       '@z_order': '0'}]},
#    {'@id': '18',
#     '@name': 'MP_SEL_B027469.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '648.46',
#       '@ytl': '190.53',
#       '@xbr': '719.90',
#       '@ybr': '314.40',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '522.35',
#       '@ytl': '158.82',
#       '@xbr': '557.30',
#       '@ybr': '179.00',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '11.30',
#       '@ytl': '0.00',
#       '@xbr': '470.74',
#       '@ybr': '1080.00',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '766.55',
#       '@ytl': '378.72',
#       '@xbr': '813.10',
#       '@ybr': '492.10',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '557.50',
#       '@ytl': '83.76',
#       '@xbr': '599.57',
#       '@ybr': '651.10',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '431.49',
#       '@ytl': '373.24',
#       '@xbr': '522.30',
#       '@ybr': '434.30',
#       '@z_order': '0'}]},
#    {'@id': '19',
#     '@name': 'MP_SEL_B027470.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1527.74',
#       '@ytl': '0.00',
#       '@xbr': '1752.40',
#       '@ybr': '965.10',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1708.95',
#       '@ytl': '494.77',
#       '@xbr': '1719.23',
#       '@ybr': '554.99',
#       '@z_order': '4'},
#      {'@label': 'bicycle',
#       '@occluded': '1',
#       '@xtl': '1085.17',
#       '@ytl': '470.77',
#       '@xbr': '1228.90',
#       '@ybr': '634.00',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1405.99',
#       '@ytl': '476.77',
#       '@xbr': '1412.23',
#       '@ybr': '513.13',
#       '@z_order': '9'},
#      {'@label': 'traffic_sign',
#       '@occluded': '0',
#       '@xtl': '1766.14',
#       '@ytl': '353.47',
#       '@xbr': '1808.80',
#       '@ybr': '396.70',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '1587.60',
#       '@ytl': '195.43',
#       '@xbr': '1632.90',
#       '@ybr': '216.30',
#       '@z_order': '0'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1576.38',
#       '@ytl': '485.95',
#       '@xbr': '1585.56',
#       '@ybr': '534.79',
#       '@z_order': '5'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1447.12',
#       '@ytl': '478.98',
#       '@xbr': '1454.46',
#       '@ybr': '520.11',
#       '@z_order': '8'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1525.70',
#       '@ytl': '482.65',
#       '@xbr': '1534.15',
#       '@ybr': '530.39',
#       '@z_order': '6'},
#      {'@label': 'bollard',
#       '@occluded': '0',
#       '@xtl': '1483.84',
#       '@ytl': '480.45',
#       '@xbr': '1490.08',
#       '@ybr': '524.51',
#       '@z_order': '7'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '1074.60',
#       '@ytl': '338.48',
#       '@xbr': '1118.70',
#       '@ybr': '553.50',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '469.00',
#       '@ytl': '229.90',
#       '@xbr': '669.10',
#       '@ybr': '809.50',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1441.41',
#       '@ytl': '431.37',
#       '@xbr': '1626.90',
#       '@ybr': '498.00',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1849.82',
#       '@ytl': '465.33',
#       '@xbr': '1920.00',
#       '@ybr': '558.50',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '1190.20',
#       '@ytl': '424.47',
#       '@xbr': '1253.70',
#       '@ybr': '636.70',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '1031.94',
#       '@ytl': '399.43',
#       '@xbr': '1064.50',
#       '@ybr': '524.70',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '984.62',
#       '@ytl': '428.40',
#       '@xbr': '1019.81',
#       '@ybr': '520.21',
#       '@z_order': '2'}]},
#    {'@id': '20',
#     '@name': 'MP_SEL_B027471.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '966.51',
#       '@ytl': '300.30',
#       '@xbr': '1050.90',
#       '@ybr': '412.90',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '0',
#       '@xtl': '1217.21',
#       '@ytl': '349.53',
#       '@xbr': '1370.00',
#       '@ybr': '613.20',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '0',
#       '@xtl': '999.74',
#       '@ytl': '320.84',
#       '@xbr': '1044.70',
#       '@ybr': '421.00',
#       '@z_order': '0'}]},
#    {'@id': '21',
#     '@name': 'MP_SEL_B027472.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '987.27',
#       '@ytl': '379.50',
#       '@xbr': '1008.70',
#       '@ybr': '450.60',
#       '@z_order': '7'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '740.77',
#       '@ytl': '210.35',
#       '@xbr': '769.41',
#       '@ybr': '483.93',
#       '@z_order': '2'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '725.35',
#       '@ytl': '0.00',
#       '@xbr': '748.48',
#       '@ybr': '483.20',
#       '@z_order': '3'},
#      {'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '737.10',
#       '@ytl': '217.70',
#       '@xbr': '787.77',
#       '@ybr': '300.32',
#       '@z_order': '4'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1386.73',
#       '@ytl': '432.94',
#       '@xbr': '1920.00',
#       '@ybr': '701.90',
#       '@z_order': '8'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1270.00',
#       '@ytl': '397.11',
#       '@xbr': '1920.00',
#       '@ybr': '621.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '677.47',
#       '@ytl': '380.90',
#       '@xbr': '712.70',
#       '@ybr': '405.60',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '688.50',
#       '@ytl': '187.60',
#       '@xbr': '735.59',
#       '@ybr': '534.80',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '632.46',
#       '@ytl': '29.90',
#       '@xbr': '691.10',
#       '@ybr': '598.89',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '267.00',
#       '@ytl': '0.00',
#       '@xbr': '461.50',
#       '@ybr': '978.00',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '0.00',
#       '@ytl': '352.00',
#       '@xbr': '237.20',
#       '@ybr': '463.40',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '1',
#       '@xtl': '732.08',
#       '@ytl': '407.63',
#       '@xbr': '828.10',
#       '@ybr': '480.00',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '865.50',
#       '@ytl': '375.94',
#       '@xbr': '915.20',
#       '@ybr': '488.90',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '590.22',
#       '@ytl': '376.17',
#       '@xbr': '646.22',
#       '@ybr': '412.47',
#       '@z_order': '0'}]},
#    {'@id': '22',
#     '@name': 'MP_SEL_B027473.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'fire_hydrant',
#       '@occluded': '0',
#       '@xtl': '214.91',
#       '@ytl': '749.90',
#       '@xbr': '306.20',
#       '@ybr': '1019.60',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '271.75',
#       '@ytl': '534.17',
#       '@xbr': '638.10',
#       '@ybr': '730.80',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '632.14',
#       '@ytl': '520.10',
#       '@xbr': '728.30',
#       '@ybr': '589.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '508.30',
#       '@xbr': '332.50',
#       '@ybr': '700.30',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '451.10',
# ...
#       '@ybr': '746.80',
#       '@z_order': '0'},
#      {'@label': 'chair',
#       '@occluded': '0',
#       '@xtl': '488.95',
#       '@ytl': '561.51',
#       '@xbr': '540.00',
#       '@ybr': '626.20',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '1595.79',
#       '@ytl': '407.19',
#       '@xbr': '1639.80',
#       '@ybr': '438.50',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '143.50',
#       '@ytl': '0.00',
#       '@xbr': '306.50',
#       '@ybr': '792.70',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '703.56',
#       '@ytl': '489.92',
#       '@xbr': '803.40',
#       '@ybr': '601.70',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '230.37',
#       '@ytl': '472.18',
#       '@xbr': '420.90',
#       '@ybr': '728.20',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '547.84',
#       '@ytl': '0.00',
#       '@xbr': '731.90',
#       '@ybr': '876.30',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1419.73',
#       '@ytl': '0.00',
#       '@xbr': '1544.50',
#       '@ybr': '682.80',
#       '@z_order': '0'}]},
#    {'@id': '293',
#     '@name': 'MP_SEL_B027744.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '386.12',
#       '@ytl': '555.41',
#       '@xbr': '665.70',
#       '@ybr': '748.70',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '678.11',
#       '@ytl': '0.00',
#       '@xbr': '717.50',
#       '@ybr': '726.40',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '489.83',
#       '@ytl': '0.00',
#       '@xbr': '559.30',
#       '@ybr': '831.40',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '572.00',
#       '@ytl': '390.30',
#       '@xbr': '630.50',
#       '@ybr': '794.50',
#       '@z_order': '4'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '886.95',
#       '@ytl': '570.34',
#       '@xbr': '909.80',
#       '@ybr': '640.60',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '1006.16',
#       '@ytl': '632.63',
#       '@xbr': '1045.50',
#       '@ybr': '699.60',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '888.04',
#       '@ytl': '584.13',
#       '@xbr': '1015.70',
#       '@ybr': '638.30',
#       '@z_order': '0'},
#      {'@label': 'bicycle',
#       '@occluded': '1',
#       '@xtl': '528.41',
#       '@ytl': '627.84',
#       '@xbr': '635.10',
#       '@ybr': '811.40',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '741.06',
#       '@ytl': '360.60',
#       '@xbr': '773.50',
#       '@ybr': '691.80',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '503.34',
#       '@xbr': '470.10',
#       '@ybr': '957.20',
#       '@z_order': '0'}]},
#    {'@id': '294',
#     '@name': 'MP_SEL_B027745.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '335.41',
#       '@ytl': '425.24',
#       '@xbr': '771.00',
#       '@ybr': '726.10',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '833.78',
#       '@ytl': '433.43',
#       '@xbr': '896.10',
#       '@ybr': '596.90',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '682.83',
#       '@ytl': '454.56',
#       '@xbr': '830.00',
#       '@ybr': '572.20',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '882.61',
#       '@ytl': '432.86',
#       '@xbr': '967.40',
#       '@ybr': '510.60',
#       '@z_order': '0'},
#      {'@label': 'traffic_sign',
#       '@occluded': '1',
#       '@xtl': '1224.79',
#       '@ytl': '102.29',
#       '@xbr': '1343.77',
#       '@ybr': '251.67',
#       '@z_order': '3'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1073.84',
#       '@ytl': '439.20',
#       '@xbr': '1173.80',
#       '@ybr': '484.80',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '479.30',
#       '@xbr': '402.40',
#       '@ybr': '957.90',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '1631.60',
#       '@ytl': '400.58',
#       '@xbr': '1917.81',
#       '@ybr': '1080.00',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '1432.68',
#       '@ytl': '546.32',
#       '@xbr': '1637.70',
#       '@ybr': '1080.00',
#       '@z_order': '0'},
#      {'@label': 'chair',
#       '@occluded': '1',
#       '@xtl': '1641.08',
#       '@ytl': '373.38',
#       '@xbr': '1852.40',
#       '@ybr': '620.00',
#       '@z_order': '6'},
#      {'@label': 'stroller',
#       '@occluded': '1',
#       '@xtl': '1410.73',
#       '@ytl': '649.97',
#       '@xbr': '1766.01',
#       '@ybr': '1080.00',
#       '@z_order': '5'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1194.16',
#       '@ytl': '0.00',
#       '@xbr': '1253.50',
#       '@ybr': '640.80',
#       '@z_order': '4'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '1013.77',
#       '@ytl': '442.34',
#       '@xbr': '1032.36',
#       '@ybr': '489.98',
#       '@z_order': '1'}]},
#    {'@id': '295',
#     '@name': 'MP_SEL_B027746.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '228.82',
#       '@ytl': '342.02',
#       '@xbr': '283.70',
#       '@ybr': '361.10',
#       '@z_order': '3'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '253.51',
#       '@ytl': '537.70',
#       '@xbr': '335.70',
#       '@ybr': '584.23',
#       '@z_order': '7'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '99.77',
#       '@ytl': '333.56',
#       '@xbr': '153.60',
#       '@ybr': '353.20',
#       '@z_order': '2'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '778.12',
#       '@ytl': '557.78',
#       '@xbr': '794.50',
#       '@ybr': '606.60',
#       '@z_order': '5'},
#      {'@label': 'person',
#       '@occluded': '1',
#       '@xtl': '795.15',
#       '@ytl': '553.79',
#       '@xbr': '816.80',
#       '@ybr': '607.20',
#       '@z_order': '6'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '562.17',
#       '@ytl': '549.88',
#       '@xbr': '629.10',
#       '@ybr': '594.90',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '77.00',
#       '@ytl': '525.00',
#       '@xbr': '216.10',
#       '@ybr': '595.90',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '0.00',
#       '@xbr': '147.20',
#       '@ybr': '1025.90',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '574.00',
#       '@ytl': '372.71',
#       '@xbr': '610.60',
#       '@ybr': '706.70',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '0',
#       '@xtl': '658.70',
#       '@ytl': '403.44',
#       '@xbr': '698.44',
#       '@ybr': '649.70',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '714.12',
#       '@ytl': '435.93',
#       '@xbr': '736.12',
#       '@ybr': '616.93',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '0',
#       '@xtl': '77.19',
#       '@ytl': '156.36',
#       '@xbr': '212.50',
#       '@ybr': '198.20',
#       '@z_order': '0'},
#      {'@label': 'traffic_light',
#       '@occluded': '1',
#       '@xtl': '329.57',
#       '@ytl': '170.46',
#       '@xbr': '454.70',
#       '@ybr': '211.00',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '626.30',
#       '@ytl': '0.00',
#       '@xbr': '664.30',
#       '@ybr': '659.40',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '757.12',
#       '@ytl': '547.39',
#       '@xbr': '773.90',
#       '@ybr': '607.70',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '1052.69',
#       '@ytl': '541.80',
#       '@xbr': '1530.40',
#       '@ybr': '814.80',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '751.17',
#       '@ytl': '510.40',
#       '@xbr': '1204.10',
#       '@ybr': '719.90',
#       '@z_order': '0'}]},
#    {'@id': '296',
#     '@name': 'MP_SEL_B027747.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '1216.90',
#       '@ytl': '597.95',
#       '@xbr': '1258.90',
#       '@ybr': '695.50',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '1450.55',
#       '@ytl': '657.94',
#       '@xbr': '1512.10',
#       '@ybr': '738.80',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '1367.66',
#       '@ytl': '622.53',
#       '@xbr': '1456.10',
#       '@ybr': '733.30',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '929.90',
#       '@ytl': '2.00',
#       '@xbr': '960.00',
#       '@ybr': '577.40',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '809.66',
#       '@ytl': '413.58',
#       '@xbr': '860.50',
#       '@ybr': '455.80',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '785.79',
#       '@ytl': '410.45',
#       '@xbr': '828.80',
#       '@ybr': '445.10',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '799.00',
#       '@ytl': '415.00',
#       '@xbr': '833.00',
#       '@ybr': '450.00',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '827.51',
#       '@ytl': '410.17',
#       '@xbr': '900.00',
#       '@ybr': '474.10',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '222.42',
#       '@xbr': '613.90',
#       '@ybr': '1080.00',
#       '@z_order': '0'}]},
#    {'@id': '297',
#     '@name': 'MP_SEL_B027748.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'motorcycle',
#       '@occluded': '1',
#       '@xtl': '754.21',
#       '@ytl': '610.75',
#       '@xbr': '848.30',
#       '@ybr': '757.30',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1439.05',
#       '@ytl': '565.00',
#       '@xbr': '1920.00',
#       '@ybr': '844.00',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '578.91',
#       '@xbr': '633.60',
#       '@ybr': '1011.60',
#       '@z_order': '0'},
#      {'@label': 'carrier',
#       '@occluded': '1',
#       '@xtl': '1166.10',
#       '@ytl': '610.86',
#       '@xbr': '1229.56',
#       '@ybr': '752.31',
#       '@z_order': '2'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '1251.31',
#       '@ytl': '0.00',
#       '@xbr': '1297.40',
#       '@ybr': '759.60',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '1555.11',
#       '@ytl': '623.68',
#       '@xbr': '1920.00',
#       '@ybr': '964.40',
#       '@z_order': '0'},
#      {'@label': 'truck',
#       '@occluded': '1',
#       '@xtl': '435.40',
#       '@ytl': '450.83',
#       '@xbr': '785.40',
#       '@ybr': '783.50',
#       '@z_order': '0'}]},
#    {'@id': '298',
#     '@name': 'MP_SEL_B027749.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'traffic_sign',
#       '@occluded': '0',
#       '@xtl': '759.20',
#       '@ytl': '322.73',
#       '@xbr': '802.20',
#       '@ybr': '369.73',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '1035.18',
#       '@ytl': '329.07',
#       '@xbr': '1105.50',
#       '@ybr': '601.10',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '896.41',
#       '@ytl': '425.49',
#       '@xbr': '939.30',
#       '@ybr': '609.10',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '300.90',
#       '@ytl': '443.54',
#       '@xbr': '520.80',
#       '@ybr': '556.50',
#       '@z_order': '0'},
#      {'@label': 'traffic_sign',
#       '@occluded': '0',
#       '@xtl': '758.57',
#       '@ytl': '275.63',
#       '@xbr': '803.40',
#       '@ybr': '322.20',
#       '@z_order': '0'},
#      {'@label': 'potted_plant',
#       '@occluded': '1',
#       '@xtl': '1002.53',
#       '@ytl': '416.21',
#       '@xbr': '1057.30',
#       '@ybr': '566.80',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '1',
#       '@xtl': '742.25',
#       '@ytl': '486.55',
#       '@xbr': '782.20',
#       '@ybr': '559.60',
#       '@z_order': '0'},
#      {'@label': 'motorcycle',
#       '@occluded': '0',
#       '@xtl': '675.89',
#       '@ytl': '478.10',
#       '@xbr': '739.40',
#       '@ybr': '583.10',
#       '@z_order': '0'},
#      {'@label': 'kiosk',
#       '@occluded': '1',
#       '@xtl': '779.36',
#       '@ytl': '365.29',
#       '@xbr': '926.10',
#       '@ybr': '539.60',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '772.24',
#       '@ytl': '0.00',
#       '@xbr': '804.20',
#       '@ybr': '562.40',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '516.00',
#       '@ytl': '0.00',
#       '@xbr': '617.00',
#       '@ybr': '793.00',
#       '@z_order': '0'},
#      {'@label': 'bus',
#       '@occluded': '1',
#       '@xtl': '0.00',
#       '@ytl': '270.54',
#       '@xbr': '337.60',
#       '@ybr': '567.00',
#       '@z_order': '0'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '1148.58',
#       '@ytl': '236.00',
#       '@xbr': '1283.80',
#       '@ybr': '695.10',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '0',
#       '@xtl': '653.63',
#       '@ytl': '442.14',
#       '@xbr': '725.50',
#       '@ybr': '488.60',
#       '@z_order': '0'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '756.79',
#       '@ytl': '441.05',
#       '@xbr': '796.90',
#       '@ybr': '468.30',
#       '@z_order': '0'}]},
#    {'@id': '299',
#     '@name': 'MP_SEL_B027750.jpg',
#     '@width': '1920',
#     '@height': '1080',
#     'box': [{'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '347.00',
#       '@ytl': '499.12',
#       '@xbr': '443.90',
#       '@ybr': '554.70',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '930.71',
#       '@ytl': '489.94',
#       '@xbr': '1038.60',
#       '@ybr': '765.20',
#       '@z_order': '0'},
#      {'@label': 'kiosk',
#       '@occluded': '0',
#       '@xtl': '690.64',
#       '@ytl': '432.69',
#       '@xbr': '844.52',
#       '@ybr': '639.98',
#       '@z_order': '3'},
#      {'@label': 'movable_signage',
#       '@occluded': '0',
#       '@xtl': '798.41',
#       '@ytl': '568.00',
#       '@xbr': '839.50',
#       '@ybr': '644.30',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '898.57',
#       '@ytl': '508.20',
#       '@xbr': '917.95',
#       '@ybr': '566.59',
#       '@z_order': '4'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '921.01',
#       '@ytl': '507.94',
#       '@xbr': '941.16',
#       '@ybr': '565.80',
#       '@z_order': '5'},
#      {'@label': 'car',
#       '@occluded': '1',
#       '@xtl': '821.59',
#       '@ytl': '514.37',
#       '@xbr': '900.80',
#       '@ybr': '583.00',
#       '@z_order': '0'},
#      {'@label': 'person',
#       '@occluded': '0',
#       '@xtl': '673.36',
#       '@ytl': '497.98',
#       '@xbr': '739.50',
#       '@ybr': '696.90',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '511.20',
#       '@ytl': '84.20',
#       '@xbr': '589.50',
#       '@ybr': '824.50',
#       '@z_order': '0'},
#      {'@label': 'tree_trunk',
#       '@occluded': '1',
#       '@xtl': '266.50',
#       '@ytl': '0.00',
#       '@xbr': '537.50',
#       '@ybr': '894.80',
#       '@z_order': '0'},
#      {'@label': 'pole',
#       '@occluded': '1',
#       '@xtl': '68.20',
#       '@ytl': '0.00',
#       '@xbr': '213.10',
#       '@ybr': '1080.00',
#       '@z_order': '0'}]}]}}

# %%
dst_dir = "/content/drive/MyDrive/FinalProject"

# %%
# bbox 정보가 dict로 주어진 경우, 해당 정보를 YOLO 형식의 레이블로 변환하여 파일에 기록하자.
for image in json_data['annotations']['image']:
        # dst_dir과 "labels"를 결합하여 새로운 디렉토리 경로를 생성
        label_path = os.path.join(dst_dir, "labels")
        print(label_path)

        file_name = image['@name'].split('.')[0]
        print(file_name)

        image_w = int(image['@width'])
        image_h = int(image['@height'])
        print(f'image_w: {image_w}, image_h: {image_h}')

        if not os.path.exists(label_path):
          os.makedirs(label_path)

        f = open(os.path.join(label_path,file_name+".txt"), 'w', encoding='UTF-8')

        # 해당 이미지에 bbox가 하나만 있는지 확인
        # image['box']가 딕셔너리 형태인지 확인
        if isinstance(image['box'], dict):
            xl = float(box['@xtl'])          # bbox 왼쪽 상단 모서리의 x 좌표
            xr = float(box['@xbr'])          # bbox 오른쪽 하단 모서리 x 좌표
            yt = float(box['@ytl'])          # bbox 왼쪽 상단 모서리의 y 좌표
            yb = float(box['@ybr'])          # bbox 오른쪽 하단 모서리의 y 좌표

            x_center = ((xl+xr)/2)           # bbox의 중심 x 좌표 계산
            x_center = x_center/image_w      # img_width로 나눠서 x 좌표 정규화

            y_center = ((yt+yb)/2)           # bbox의 중심 y 좌표 계산
            y_center = y_center/image_h      # img_height로 나눠서 y 좌표 정규화

            w = (xr-xl)/image_w                 # bbox_width를 image_width로 나눠서 정규화
            h = (yb-yt)/image_h                 # bbox_height를 image_height로 나눠서 정규화

            x_center = format(x_center, '.6f')
            y_center = format(y_center, '.6f')
            w = format(w, '.6f')
            h = format(h, '.6f')

            label = label_dict[box['@label']]   # bbox label 추출

            # 레이블과 좌표 정보를 문자열로 변환하고 리스트로 변환
            arr = list(map(str, [label, x_center, y_center, w, h]))
            data = ' '.join(arr) + '\n'
            f.write(data)


        # 이미지에 여러 개의 바운딩 박스가 있는 경우
        # 리스트에 있는 각 바운딩 박스에 대해 반복문을 실행합
        else:
            for box in image['box']:
                xl = float(box['@xtl'])
                xr = float(box['@xbr'])
                yt = float(box['@ytl'])
                yb = float(box['@ybr'])

                x_center = ((xl+xr)/2)
                x_center = x_center/image_w

                y_center = ((yt+yb)/2)
                y_center = y_center/image_h

                w = (xr-xl)/image_w
                h = (yb-yt)/image_h

                x_center = format(x_center, '.6f')
                y_center = format(y_center, '.6f')
                w = format(w, '.6f')
                h = format(h, '.6f')

                label = label_dict[box['@label']]
                arr = list(map(str, [label, x_center, y_center, w, h]))
                data = ' '.join(arr) + '\n'
                f.write(data)
        f.close()

# %%
eg_ref = '/content/drive/MyDrive/FinalProject/labels/MP_SEL_B027534.txt'

with open(eg_ref, 'r', encoding='UTF-8') as file:
    content = file.read()

# (label, x_center, y_center, w, h) 순서로 데이터가 들어가 있는 것 확인!
print(content)
# Out:
# 2 0.831401 0.685509 0.337198 0.628981
# 21 0.070563 0.710620 0.078250 0.151352
# 21 0.260490 0.647046 0.024021 0.106833
# 2 0.465635 0.516472 0.079354 0.111685
# 20 0.589583 0.265648 0.011458 0.531296
# 20 0.346458 0.335324 0.037396 0.670648
# 21 0.326380 0.626958 0.036927 0.098861
# 2 0.498966 0.473537 0.038318 0.065519
# 21 0.118172 0.747815 0.138135 0.222519
# 21 0.295354 0.632574 0.032313 0.100778
# 0 0.383185 0.533773 0.027276 0.092454
# 8 0.179016 0.595593 0.059375 0.301852
# 27 0.506518 0.379431 0.022026 0.026565
# 2 0.541771 0.484583 0.046250 0.066574

# %% [markdown]
# ### Final; Inference code

# %%
import os
import cv2
import torch
import json
import math
from pathlib import Path
#from app.utils import dir_func
import numpy as np

# %%
from ultralytics.nn.autobackend import AutoBackend
from ultralytics.yolo.data.dataloaders.stream_loaders import LoadImages
from ultralytics.yolo.utils.checks import check_imgsz
from ultralytics.yolo.utils.plotting import Annotator, colors
from ultralytics.yolo.utils.ops import scale_boxes, non_max_suppression
from ultralytics.yolo.engine.results import Results

# %%
# 바운딩 박스가 이미지 내 어느 영역에 위치하는지를 결정
def find_location_idx(img_w, x_min, x_max):  # bbox의 최소,최대 x 좌표
    left_th = img_w // 3                     # 좌측 임계값은 이미지 폭의 1/3
    center_th = img_w * 2 // 3               # 중앙 임계값은 이미지 폭의 2/3
    x_center = (x_min + x_max) // 2
    if x_center < left_th:
        return 0
    elif x_center < center_th:
        return 1
    else:
        return 2

# %%
# bbox 위치에 따라 해당 bbox와 이미지 중심 간의 거리와 헤딩(방향)을 계산
def distance_heading(img_w, img_h, x_min, x_max, y_min, y_max):    # bbox 좌표
    delta_x = (x_min + x_max) / 2 - img_w / 2                      # x 좌표 중심이 이미지의 가운데로부터 얼마나 떨어져 있는지
    delta_y = y_max - img_h                                        # bbox의 상단이 이미지의 하단으로부터 얼마나 떨어져 있는지

    distance = math.sqrt(delta_x ** 2 + delta_y ** 2)              # bbox의 중심과 이미지 중심 간의 거리를 계산(유클리드)
    heading = -math.atan2(-delta_y, delta_x) * 180 / math.pi       # bbox의 중심을 향하는 방향을 나타내는 헤딩을 계산(아크탄젠트)
    return distance, heading                                       # 계산된 거리와 헤딩을 튜플로 묶어 반환

# %%
def detect(src: str, session_id: str, conf_thres=0.25, THRESHOLD_y=0.7):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    print('Inference with', device)

    tmp_path = os.path.join(APP_PATH, "tmp", session_id)
    img_dst = os.path.join(tmp_path, "img_dir")
    TXT_FILE = os.path.join(tmp_path, f'dist_degree.txt')
    dir_func(img_dst, rmtree=False, mkdir=True)

    model = AutoBackend(weights=os.path.join(MODEL_DIR, "yolov8", 'yolov8n_custom.pt'), device=device, dnn=False, fp16=False)
    model.eval()

    stride, names, pt = model.stride, model.names, model.pt
    imgsz = check_imgsz((640, 640), stride=stride)
    dataset = LoadImages(src, imgsz=imgsz, stride=stride, auto=pt, vid_stride=1)

    for batch in dataset:
        _, img_nparr, im0s, vid_cap, s = batch
        mask_h, mask_w, _ = im0s.shape
        mask = np.zeros(im0s.shape, np.uint8)
        mask_thres1 = np.zeros((mask_h, mask_w), np.uint8)
        mask_thres2 = np.zeros((mask_h, mask_w), np.uint8)
        break

    json_obj = {}
    # threshold line settings
    far = 0.18
    middle = 0.145
    near = 0.1

    # threshold angle settings
    angle_far = 15
    angle_middle = 30
    angle_near = 90
    angle_center = 270

    # ellipse ratio
    ellipse_value = 2.5

    # color settings
    YELLOW = (0, 255, 255)
    RED = (0, 0, 255)

    # masking value
    bitmask = 255

    # mask = np.zeros((720,1280,3),np.uint8)
    cv2.ellipse(mask, (int(mask_w / 2), mask_h), (int(mask_h * far * ellipse_value), int(mask_h * far)), 0, angle_center - angle_near, angle_center + angle_near, YELLOW, -1)
    cv2.ellipse(mask, (int(mask_w / 2), mask_h), (int(mask_h * near * ellipse_value), int(mask_h * near)), 0, angle_center - angle_near, angle_center + angle_near, RED, -1)
    cv2.ellipse(mask, (int(mask_w / 2), mask_h), (int(mask_h * middle * ellipse_value), int(mask_h * middle)), 0, angle_center - angle_middle, angle_center + angle_middle, RED, -1)
    cv2.ellipse(mask, (int(mask_w / 2), mask_h), (int(mask_h * far * ellipse_value), int(mask_h * far)), 0, angle_center - angle_far, angle_center + angle_far, RED, -1)

    # mask_thres1
    cv2.ellipse(mask_thres1, (int(mask_w / 2), mask_h), (int(mask_h * far * ellipse_value), int(mask_h * far)), 0, angle_center - angle_near, angle_center + angle_near, bitmask, -1)
    # mask_thres2
    cv2.ellipse(mask_thres2, (int(mask_w / 2), mask_h), (int(mask_h * near * ellipse_value), int(mask_h * near)), 0, angle_center - angle_near, angle_center + angle_near, bitmask, -1)
    cv2.ellipse(mask_thres2, (int(mask_w / 2), mask_h), (int(mask_h * middle * ellipse_value), int(mask_h * middle)), 0, angle_center - angle_middle, angle_center + angle_middle, bitmask, -1)
    cv2.ellipse(mask_thres2, (int(mask_w / 2), mask_h), (int(mask_h * far * ellipse_value), int(mask_h * far)), 0, angle_center - angle_far, angle_center + angle_far, bitmask, -1)

    import time
    t1 = time.time()

    for frame_idx, batch in enumerate(dataset, 1):
        _, img_nparr, im0s, vid_cap, s = batch
        annotator = Annotator(im0s, line_width=2, example=str(names))  # disable when time measurement
        img_nparr = torch.from_numpy(img_nparr)

        img_nparr = img_nparr.float()
        img_nparr /= 255.0
        if len(img_nparr.shape) == 3:
            img_nparr = img_nparr[None]

        img_nparr = img_nparr.to(device)
        bboxes_data = non_max_suppression(model(img_nparr), conf_thres=conf_thres, iou_thres=0.45, classes=None, agnostic=False, max_det=1000)

        for i, bbox in enumerate(bboxes_data):
            shape = im0s[i].shape if isinstance(im0s, list) else im0s.shape
            img_h, img_w, _ = shape
            bbox[:, :4] = scale_boxes(img_nparr.shape[2:], bbox[:, :4], (img_h, img_w)).round()

            json_obj[f'{frame_idx:04d}'] = {}
            # warn_obj=[]
            with open(TXT_FILE, 'a') as f:
                f.write(f'{frame_idx:04d}:\n')
                for obj_id, obj in enumerate(reversed(Results(boxes=bbox, orig_shape=(img_h, img_w)).boxes), 1):
                    bbox = obj.xyxy.squeeze()
                    x_min, y_min, x_max, y_max = bbox_list = bbox.tolist()

                    dist, angle = distance_heading(img_w, img_h, *bbox_list)

                    f.write(f'{obj_id:02d} {dist:.1f} {angle:.1f} {bbox}\n')

                    warn = 3
                    np_size = (int(y_max - y_min), int(x_max - x_min))

                    if np.any((mask_thres1[int(y_min):int(y_max), int(x_min):int(x_max)] & np.ones(np_size, np.uint8)) > 0):
                        warn = 2
                        if np.any((mask_thres2[int(y_min):int(y_max), int(x_min):int(x_max)] & np.ones(np_size, np.uint8)) > 0):
                            warn = 1
                    cls = obj.cls.squeeze()
                    c = int(cls)
                    label = f'{model.names[c]}'
                    annotator.box_label(bbox, label, color=colors(4 * (warn - 1), True))  # disable when time measurement

                    json_obj[f'{frame_idx:04d}'][f'{obj_id:02d}'] = {"class": f'{model.names[c]}',
                                                                     "warning_lv": f"{warn}",
                                                                     "location": f'{find_location_idx(img_w, x_min, x_max)}',
                                                                     "distance": round(dist, 2),
                                                                     "heading": round(angle, 1)}

        cv2.imwrite(os.path.join(img_dst, f"{frame_idx:04}.jpg"), cv2.addWeighted(mask, 0.2, annotator.result(), 0.8, 0))  # disable when time measurement
        # cv2.imwrite(os.path.join(img_dst, f"{frame_idx:04}.jpg"), im0s)  # enable when time measurement

    elapsedtime = time.time() - t1
    print(f'Inference time {elapsedtime}/Frames {frame_idx}')  # time measurement

    return json.dumps(json_obj, ensure_ascii=False, indent=None, sort_keys=True)
